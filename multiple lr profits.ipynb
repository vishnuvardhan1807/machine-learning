# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
# Out:
# C:\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# ...

# %%
df = pd.read_csv("Restaurant.csv")
df
# Out:
#     Miscellaneous_Expenses  Food_Innovation_Spend  Advertising     City  \
# 0                138671.80              167497.20    475918.10  Chicago
# 1                153151.59              164745.70    448032.53   Mumbai
# 2                102919.55              155589.51    412068.54    Tokyo
# 3                120445.85              146520.41    387333.62  Chicago
# 4                 93165.77              144255.34    370302.42    Tokyo
# 5                101588.71              134024.90    366995.36  Chicago
# 6                148972.87              136763.46    131850.82   Mumbai
# 7                147304.06              132446.13    328010.68    Tokyo
# 8                150492.95              122690.52    315747.29  Chicago
# 9                110453.17              125482.88    309115.62   Mumbai
# 10               112368.11              104061.08    233294.95    Tokyo
# 11                93564.61              102819.96    253878.55   Mumbai
# ...

# %%
df.shape
# Out:
# (50, 5)

# %%
plt.figure(figsize=[10,10])
plt.scatter(df.Miscellaneous_Expenses,df.Profit,color="red")
plt.scatter(df.Food_Innovation_Spend,df.Profit,color="yellow")
plt.scatter(df.Advertising,df.Profit,color="blue")
plt.show()

# %%
a = pd.get_dummies(df.City)
a
# Out:
#     Chicago  Mumbai  Tokyo
# 0         1       0      0
# 1         0       1      0
# 2         0       0      1
# 3         1       0      0
# 4         0       0      1
# 5         1       0      0
# 6         0       1      0
# 7         0       0      1
# 8         1       0      0
# 9         0       1      0
# 10        0       0      1
# 11        0       1      0
# 12        0       0      1
# 13        0       1      0
# 14        0       0      1
# 15        1       0      0
# 16        0       1      0
# 17        1       0      0
# 18        0       0      1
# 19        1       0      0
# 20        0       1      0
# 21        1       0      0
# 22        0       0      1
# 23        0       0      1
# 24        1       0      0
# 25        0       1      0
# 26        0       0      1
# 27        1       0      0
# 28        0       0      1
# 29        1       0      0
# 30        0       0      1
# 31        1       0      0
# 32        0       1      0
# ...

# %%
df1 = pd.concat([df,a],axis=1)

# %%
df1
# Out:
#     Miscellaneous_Expenses  Food_Innovation_Spend  Advertising     City  \
# 0                138671.80              167497.20    475918.10  Chicago
# 1                153151.59              164745.70    448032.53   Mumbai
# 2                102919.55              155589.51    412068.54    Tokyo
# 3                120445.85              146520.41    387333.62  Chicago
# 4                 93165.77              144255.34    370302.42    Tokyo
# 5                101588.71              134024.90    366995.36  Chicago
# 6                148972.87              136763.46    131850.82   Mumbai
# 7                147304.06              132446.13    328010.68    Tokyo
# 8                150492.95              122690.52    315747.29  Chicago
# 9                110453.17              125482.88    309115.62   Mumbai
# 10               112368.11              104061.08    233294.95    Tokyo
# 11                93564.61              102819.96    253878.55   Mumbai
# ...

# %%
df1.drop(["Chicago","City"],inplace = True,axis=1)

# %%
df1
# Out:
#     Miscellaneous_Expenses  Food_Innovation_Spend  Advertising     Profit  \
# 0                138671.80              167497.20    475918.10  202443.83
# 1                153151.59              164745.70    448032.53  201974.06
# 2                102919.55              155589.51    412068.54  201232.39
# 3                120445.85              146520.41    387333.62  193083.99
# 4                 93165.77              144255.34    370302.42  176369.94
# 5                101588.71              134024.90    366995.36  167173.12
# 6                148972.87              136763.46    131850.82  166304.51
# 7                147304.06              132446.13    328010.68  165934.60
# 8                150492.95              122690.52    315747.29  162393.77
# 9                110453.17              125482.88    309115.62  159941.96
# 10               112368.11              104061.08    233294.95  156303.95
# 11                93564.61              102819.96    253878.55  154441.40
# ...

# %%
input = df1.drop("Profit",axis=1)

# %%
input
# Out:
#     Miscellaneous_Expenses  Food_Innovation_Spend  Advertising  Mumbai  Tokyo
# 0                138671.80              167497.20    475918.10       0      0
# 1                153151.59              164745.70    448032.53       1      0
# 2                102919.55              155589.51    412068.54       0      1
# 3                120445.85              146520.41    387333.62       0      0
# 4                 93165.77              144255.34    370302.42       0      1
# 5                101588.71              134024.90    366995.36       0      0
# 6                148972.87              136763.46    131850.82       1      0
# 7                147304.06              132446.13    328010.68       0      1
# 8                150492.95              122690.52    315747.29       0      0
# 9                110453.17              125482.88    309115.62       1      0
# 10               112368.11              104061.08    233294.95       0      1
# ...

# %%
x  = input.values

# %%
x.ndim
# Out:
# 2

# %%
y = df1["Profit"].values

# %%
y.ndim
# Out:
# 1

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.3,random_state=10)

# %%
len(y_train)
# Out:
# 35

# %%
len(x_test)
# Out:
# 15

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = reg.predict(x_test)
y_predict
# Out:
# array([ 98929.29562586, 118467.64828057,  77741.62122414,  81797.5477672 ,
#         59649.88493176, 126769.75381426, 181021.4955706 , 108770.69604143,
#        168103.40321397, 168160.70666823,  94120.28393204, 188241.49024321,
#         86460.75354891, 110387.00057172, 143457.08414743])

# %%
reg.score(x_test,y_test)
# Out:
# 0.9796796125080645

# %%
reg.predict([[138671.80,167497.20,475918.10,0,0]])
# Out:
# array([199690.3105987])

# %%
type(reg.predict(x_train))
# Out:
# numpy.ndarray

# %%
reg.predict(x_train).ndim
# Out:
# 1

# %%
x_train.ndim
# Out:
# 2

# %%
a = x_train.flatten()

# %%
a.ndim
# Out:
# 1

# %%
plt.scatter(a,)
